# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# !pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\tran\anaconda3\lib\site-packages (from gmaps) (7.12.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\tran\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\tran\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in c:\users\tran\anaconda3\lib\site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.14.1)
# Requirement already satisfied: pickleshare in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.3)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (45.2.0.post20200210)
# Requirement already satisfied: pygments in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.5.2)
# Requirement already satisfied: decorator in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.1)
# Requirement already satisfied: backcall in c:\users\tran\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tran\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\tran\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\tran\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipython-genutils in c:\users\tran\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: parso>=0.5.0 in c:\users\tran\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\tran\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.8)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\tran\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\tran\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.1)
# Requirement already satisfied: jupyter-client in c:\users\tran\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\tran\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tran\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\tran\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tran\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\tran\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\tran\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\tran\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\tran\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\tran\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: nbconvert in c:\users\tran\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: Send2Trash in c:\users\tran\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\tran\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: prometheus-client in c:\users\tran\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tran\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: bleach in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: defusedxml in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: testpath in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\tran\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tran\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: webencodings in c:\users\tran\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076101 sha256=10f05fa751d697225e4eece844c5bab1c76e98f10fbcc84aca50a38ddbd2702e
#   Stored in directory: c:\users\tran\appdata\local\pip\cache\wheels\3d\1c\cb\c46f4199210e632b28d78d05a00bfdccbf6dfcd3f5b051d6bf
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0

# %%
# !pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.2-cp37-cp37m-win_amd64.whl (6.8 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\tran\anaconda3\lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\tran\anaconda3\lib\site-packages (from scikit-learn) (0.14.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\tran\anaconda3\lib\site-packages (from scikit-learn) (1.4.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.1
#     Uninstalling scikit-learn-0.22.1:
#       Successfully uninstalled scikit-learn-0.22.1
# Successfully installed scikit-learn-0.23.2 threadpoolctl-2.1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
# Out:
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\TRAN\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Import our input dataset
vgsales_df = pd.read_csv('vgsales-12-4-2019.csv')
vgsales_df.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# 0             NaN           7.7  ...       NaN        NaN       NaN
# 1             NaN          10.0  ...       NaN        NaN       NaN
# 2             NaN           8.2  ...       NaN        NaN       NaN
# 3             NaN           NaN  ...       NaN        NaN       NaN
# 4             NaN           8.0  ...       NaN        NaN       NaN
#
#    Other_Sales    Year  Last_Update  \
# 0          NaN  2006.0          NaN
# 1          NaN  1985.0          NaN
# 2          NaN  2008.0  11th Apr 18
# 3          NaN  2017.0  13th Nov 18
# 4          NaN  2009.0          NaN
#
#                                                  url  status Vgchartzscore  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...       1           NaN
# 1  http://www.vgchartz.com/game/6455/super-mario-...       1           NaN
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...       1           8.7
# 3  http://www.vgchartz.com/game/215988/playerunkn...       1           NaN
# 4  http://www.vgchartz.com/game/24656/wii-sports-...       1           8.8
#
#                                          img_url
# 0  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1                   /games/boxart/8972270ccc.jpg
# 2  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4  /games/boxart/full_7295041AmericaFrontccc.jpg
#
# [5 rows x 23 columns]

# %%
vgsales_df.columns.tolist()
# Out:
# ['Rank',
#  'Name',
#  'basename',
#  'Genre',
#  'ESRB_Rating',
#  'Platform',
#  'Publisher',
#  'Developer',
#  'VGChartz_Score',
#  'Critic_Score',
#  'User_Score',
#  'Total_Shipped',
#  'Global_Sales',
#  'NA_Sales',
#  'PAL_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Year',
#  'Last_Update',
#  'url',
#  'status',
#  'Vgchartzscore',
#  'img_url']

# %%
vgsales_df.dtypes
# Out:
# Rank                int64
# Name               object
# basename           object
# Genre              object
# ESRB_Rating        object
# Platform           object
# Publisher          object
# Developer          object
# VGChartz_Score    float64
# Critic_Score      float64
# User_Score        float64
# Total_Shipped     float64
# Global_Sales      float64
# NA_Sales          float64
# PAL_Sales         float64
# JP_Sales          float64
# Other_Sales       float64
# Year              float64
# Last_Update        object
# url                object
# status              int64
# Vgchartzscore     float64
# img_url            object
# dtype: object

# %%
vgsales_df.count()
# Out:
# Rank              55792
# Name              55792
# basename          55792
# Genre             55792
# ESRB_Rating       23623
# Platform          55792
# Publisher         55792
# Developer         55775
# VGChartz_Score        0
# Critic_Score       6536
# User_Score          335
# Total_Shipped      1827
# Global_Sales      19415
# NA_Sales          12964
# PAL_Sales         13189
# JP_Sales           7043
# Other_Sales       15522
# Year              54813
# Last_Update        9186
# url               55792
# status            55792
# Vgchartzscore       799
# img_url           55792
# dtype: int64

# %%
# Drop columns:
# Rank: just numbers in order, not real ranking
# status: only one status 1, not sure what is that
# Last_Update: unneccessary
# VGChartz_Score: no values
vgsales_df = vgsales_df.drop(['Rank', 'Last_Update', 'status'], axis = 1)
vgsales_df.head(5)
# Out:
#                             Name                      basename     Genre  \
# 0                     Wii Sports                    wii-sports    Sports
# 1              Super Mario Bros.              super-mario-bros  Platform
# 2                 Mario Kart Wii                mario-kart-wii    Racing
# 3  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds   Shooter
# 4              Wii Sports Resort             wii-sports-resort    Sports
#
#   ESRB_Rating Platform         Publisher         Developer  VGChartz_Score  \
# 0           E      Wii          Nintendo      Nintendo EAD             NaN
# 1         NaN      NES          Nintendo      Nintendo EAD             NaN
# 2           E      Wii          Nintendo      Nintendo EAD             NaN
# 3         NaN       PC  PUBG Corporation  PUBG Corporation             NaN
# 4           E      Wii          Nintendo      Nintendo EAD             NaN
#
#    Critic_Score  User_Score  Total_Shipped  Global_Sales  NA_Sales  PAL_Sales  \
# 0           7.7         NaN          82.86           NaN       NaN        NaN
# 1          10.0         NaN          40.24           NaN       NaN        NaN
# 2           8.2         9.1          37.14           NaN       NaN        NaN
# 3           NaN         NaN          36.60           NaN       NaN        NaN
# 4           8.0         8.8          33.09           NaN       NaN        NaN
#
#    JP_Sales  Other_Sales    Year  \
# 0       NaN          NaN  2006.0
# 1       NaN          NaN  1985.0
# 2       NaN          NaN  2008.0
# 3       NaN          NaN  2017.0
# 4       NaN          NaN  2009.0
#
#                                                  url  Vgchartzscore  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...            NaN
# 1  http://www.vgchartz.com/game/6455/super-mario-...            NaN
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...            8.7
# 3  http://www.vgchartz.com/game/215988/playerunkn...            NaN
# 4  http://www.vgchartz.com/game/24656/wii-sports-...            8.8
#
#                                          img_url
# 0  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1                   /games/boxart/8972270ccc.jpg
# 2  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4  /games/boxart/full_7295041AmericaFrontccc.jpg

# %%
vgsales_df.count()
# Out:
# Name              55792
# basename          55792
# Genre             55792
# ESRB_Rating       23623
# Platform          55792
# Publisher         55792
# Developer         55775
# VGChartz_Score        0
# Critic_Score       6536
# User_Score          335
# Total_Shipped      1827
# Global_Sales      19415
# NA_Sales          12964
# PAL_Sales         13189
# JP_Sales           7043
# Other_Sales       15522
# Year              54813
# url               55792
# Vgchartzscore       799
# img_url           55792
# dtype: int64
